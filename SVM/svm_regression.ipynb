# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/cement_slump.csv')

# %%
df.head()
# Out:
#    Cement   Slag  Fly ash  Water    SP  Coarse Aggr.  Fine Aggr.  SLUMP(cm)  \
# 0   273.0   82.0    105.0  210.0   9.0         904.0       680.0       23.0
# 1   163.0  149.0    191.0  180.0  12.0         843.0       746.0        0.0
# 2   162.0  148.0    191.0  179.0  16.0         840.0       743.0        1.0
# 3   162.0  148.0    190.0  179.0  19.0         838.0       741.0        3.0
# 4   154.0  112.0    144.0  220.0  10.0         923.0       658.0       20.0
#
#    FLOW(cm)  Compressive Strength (28-day)(Mpa)
# 0      62.0                               34.99
# 1      20.0                               41.14
# 2      20.0                               41.81
# 3      21.5                               42.08
# 4      64.0                               26.82

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('Compressive Strength (28-day)(Mpa)', axis=1), df['Compressive Strength (28-day)(Mpa)'], test_size=0.3, random_state=42)

# %%
from sklearn.svm import SVR, LinearSVR

# %%
pipe = Pipeline([('scaler', StandardScaler(), 'svr', SVR())])

# %%
pipe.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 pipe.fit(X_train, y_train)
#
# File c:\Python\VSCPython\Models\.venv\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Python\VSCPython\Models\.venv\Lib\site-packages\sklearn\pipeline.py:612, in Pipeline.fit(self, X, y, **params)
#     605 if not _routing_enabled() and self.transform_input is not None:
#     606     raise ValueError(
#     607         "The `transform_input` parameter can only be set if metadata "
# ...
